# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

from sklearn.svm  import SVC

# %%
data= pd.read_csv("./iris.csv")
data
# Out:
#                       Sepal.Length            Sepal.Width  \
# 0                              5.1                    3.5
# 1                              4.9                      3
# 2                              4.7                    3.2
# 3                              4.6                    3.1
# 4                                5                    3.6
# ..                             ...                    ...
# 161                           data                    NaN
# 162                    Build Model                    NaN
# 163  Visualize Model using mlxtend                    NaN
# 164            --sns.pairplot(data  x_vars="Petal.Length"
# 165   Create Multi Class SVM model                    NaN
#
#              Petal.Length  Petal.Width    Species
# 0                     1.4          0.2     setosa
# 1                     1.4          0.2     setosa
# 2                     1.3          0.2     setosa
# 3                     1.5          0.2     setosa
# 4                     1.4          0.2     setosa
# ..                    ...          ...        ...
# 161                   NaN          NaN        NaN
# 162                   NaN          NaN        NaN
# 163                   NaN          NaN        NaN
# 164  y_vars="Petal.Width"   hue="v_nv"  height=5)
# 165                   NaN          NaN        NaN
#
# [166 rows x 5 columns]

# %%
v = lambda x:0 if x=="versicolor" else 1 
data["v_nv"]=data["Species"].apply(v)
data
# Out:
#                       Sepal.Length            Sepal.Width  \
# 0                              5.1                    3.5
# 1                              4.9                      3
# 2                              4.7                    3.2
# 3                              4.6                    3.1
# 4                                5                    3.6
# ..                             ...                    ...
# 161                           data                    NaN
# 162                    Build Model                    NaN
# 163  Visualize Model using mlxtend                    NaN
# 164            --sns.pairplot(data  x_vars="Petal.Length"
# 165   Create Multi Class SVM model                    NaN
#
#              Petal.Length  Petal.Width    Species  v_nv
# 0                     1.4          0.2     setosa     1
# 1                     1.4          0.2     setosa     1
# 2                     1.3          0.2     setosa     1
# 3                     1.5          0.2     setosa     1
# 4                     1.4          0.2     setosa     1
# ..                    ...          ...        ...   ...
# 161                   NaN          NaN        NaN     1
# 162                   NaN          NaN        NaN     1
# 163                   NaN          NaN        NaN     1
# 164  y_vars="Petal.Width"   hue="v_nv"  height=5)     1
# 165                   NaN          NaN        NaN     1
#
# [166 rows x 6 columns]

# %%
sns.pairplot(data,x_vars="Petal.Length",y_vars="Petal.Width", hue="v_nv",height=5)

# %%
X=data[["Petal.Length","Petal.Width"]]
y=data["v_nv"]
model=SVC()
model.fit(X,y)
model.score(X,y)

# %%
# Assuming data is your DataFrame
# First, ensure that "Species" column is of type category or object
data['Species'] = data['Species'].astype(str)

# Then, replace the string values with numeric values
data.loc[data['Species'] == 'setosa', 'Species'] = 0
data.loc[data['Species'] == 'versicolor', 'Species'] = 1
data.loc[data['Species'] == 'virginica', 'Species'] = 2

# Finally, convert the column back to category type if needed
data['Species'] = data['Species'].astype('category')
data
# Out:
#                       Sepal.Length            Sepal.Width  \
# 0                              5.1                    3.5
# 1                              4.9                      3
# 2                              4.7                    3.2
# 3                              4.6                    3.1
# 4                                5                    3.6
# ..                             ...                    ...
# 161                           data                    NaN
# 162                    Build Model                    NaN
# 163  Visualize Model using mlxtend                    NaN
# 164            --sns.pairplot(data  x_vars="Petal.Length"
# 165   Create Multi Class SVM model                    NaN
#
#              Petal.Length  Petal.Width    Species  v_nv
# 0                     1.4          0.2          0     1
# 1                     1.4          0.2          0     1
# 2                     1.3          0.2          0     1
# 3                     1.5          0.2          0     1
# 4                     1.4          0.2          0     1
# ..                    ...          ...        ...   ...
# 161                   NaN          NaN        nan     1
# 162                   NaN          NaN        nan     1
# 163                   NaN          NaN        nan     1
# 164  y_vars="Petal.Width"   hue="v_nv"  height=5)     1
# 165                   NaN          NaN        nan     1
#
# [166 rows x 6 columns]
